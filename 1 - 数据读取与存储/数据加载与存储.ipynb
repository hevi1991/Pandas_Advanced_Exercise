# %% [markdown]
# # pandas 进阶修炼 ｜早起 Python
#
# <br>
#
# **本习题由公众号【早起 Python & 可视化图鉴】 原创，转载及其他形式合作请与我们联系（微信号`sshs321`)，未经授权严禁搬运及二次创作，侵权必究！**
#
# 本习题基于 `pandas` 版本 `1.1.3`，所有内容应当在 `Jupyter Notebook` 中执行以获得最佳效果。
#
# 不同版本之间写法可能会有少许不同，如若碰到此情况，你应该学会如何自行检索解决。

# %% [markdown]
# # 1 - 数据加载与存储

# %% [markdown]
# 是的，常常被忽略的「<font color=#E36C07>**数据加载与存储**</font>」也大有门道且值得作为本套习题的开门之章。
#
# 在一次数据分析的过程中，你可能只会读取或存储一两次数据集。
#
# **但若能灵活掌握各项设置，在读取阶段就将数据筛选、匹配、格式指定等操作完成，有时会为我们节省大量时间。**
#
# 在本节习题中，我将 pandas 数据分析中常见的数据读取与存储操作进行整理。
#
# <font color=#E36C07>**既可以用于巩固、学习各种操作，也可以作为速查手册使用**</font>。

# %% [markdown]
# ## 初始化
#
# <br>
#
# 该 `Notebook` 版本为**纯习题版**
#
# 如果需要答案或者提示，可以微信搜索公众号「早起 Python」获取！

# %% [markdown]
# ## 1-1 数据读取

# %% [markdown]
# ### 1 读取 Excel 文件
#
# <br>
#
# - 读取当前目录下 `某招聘网站数据.csv` 文件
#
# - 读取当前目录下 `TOP250.xlsx` 文件
#
# **注意**：使用 `pandas` 读取 `CSV` 与 读取 `xlsx` 格式的 `Excel` 文件方法大致相同
#
# 因此接下来与 `Excel` 相关的操作均以 `CSV` 格式进行出题。

# %%
import pandas as pd

data = pd.read_csv("某招聘网站数据.csv")
data = pd.read_excel("TOP250.xlsx")

# %% [markdown]
# ### 2 读取 Excel 文件｜指定位置
#
# 在大多数情况下，我们会将 `notebook` 和数据源文件放在同一个目录（文件夹下），这样直接使用`pd.read_xxx("文件名")`即可成功读取。
#
# 但有时需要读取的文件和 `notebook` 不在同一个目录下，这时可以使用绝对路径或者相对本 `notebook` 的路径。
#
# 现在请读取本套习题中第二章节下的数据，即 `2 - 个性化显示设置/data.csv`

# %%
pd.read_csv("../2 - 个性化显示设置/data.csv")
# Out:
#      positionId           positionName  companyId companySize industryField  \
# 0       6802721                   数据分析     475770     50-150人      移动互联网,电商
# 1       5204912                   数据建模      50735    150-500人            电商
# 2       6877668                   数据分析     100125     2000人以上    移动互联网,企业服务
# 3       6496141                   数据分析      26564   500-2000人            电商
# 4       6467417                   数据分析      29211     2000人以上         物流丨运输
# ..          ...                    ...        ...         ...           ...
# 100     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 101     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#     financeStage                   companyLabelList  firstType secondType  \
# 0             A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1             B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2           上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3          D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4           上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# ..           ...                                ...        ...        ...
# 100           C轮   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 101           C轮   ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 102        不需要融资                                 []  开发|测试|运维类       数据开发
# 103         上市公司   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 104        不需要融资   ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#     thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0        数据分析  ...  NaN      0       0       0              NaN
# 1          建模  ...  NaN      0       0       0              NaN
# 2        数据分析  ...  NaN      0       0       0              NaN
# 3        数据分析  ...  NaN      0       0       0              NaN
# 4        数据分析  ...  NaN      0       0       0              NaN
# ..        ...  ...  ...    ...     ...     ...              ...
# 100      数据分析  ...  NaN      0       0       0              NaN
# 101    商业数据分析  ...  NaN      0       0       0              NaN
# 102      数据分析  ...  NaN      0       0       0              NaN
# 103      数据分析  ...  NaN      0       0       0              NaN
# 104    其他数据分析  ...  NaN      0       0       0              NaN
#
#     promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                     NaN         0      0                   []         False
# 1                     NaN         0      0                   []         False
# 2                     NaN         0      0                   []         False
# 3                     NaN         0      0                   []          True
# 4                     NaN         0      0                   []          True
# ..                    ...       ...    ...                  ...           ...
# 100                   NaN         0      0                   []         False
# 101                   NaN         0      0                   []         False
# 102                   NaN         0      0                   []         False
# 103                   NaN         0      0                   []          True
# 104                   NaN         0      0                   []          True
#
# [105 rows x 52 columns]

# %% [markdown]
# ### 3 读取 Excel 文件｜指定行（顺序）
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件的 <font color = '#5F5FFC'>前 20 行</font>

# %%
pd.read_csv("./某招聘网站数据.csv").head(20)
# Out:
#     positionId      positionName  companyId companySize industryField  \
# 0      6802721              数据分析     475770     50-150人      移动互联网,电商
# 1      5204912              数据建模      50735    150-500人            电商
# 2      6877668              数据分析     100125     2000人以上    移动互联网,企业服务
# 3      6496141              数据分析      26564   500-2000人            电商
# 4      6467417              数据分析      29211     2000人以上         物流丨运输
# 5      6882347              数据分析      94826     50-150人      移动互联网,社交
# 6      6841659              数据分析     348784     50-150人      移动互联网,电商
# 7      6764018           数据建模工程师      13163   500-2000人         移动互联网
# 8      6458372            数据分析专家      34132    150-500人     数据服务,广告营销
# 9      6786904             数据分析师      13163   500-2000人         移动互联网
# 10     6804629             数据分析师      34132    150-500人     数据服务,广告营销
# 11     6847013  大数据分析工程师(J11108)      55046     2000人以上    移动互联网,企业服务
# 12     6763962           数据分析工程师      13163   500-2000人         移动互联网
# 13     6804489           资深数据分析师      34132    150-500人     数据服务,广告营销
# 14     6657285             数据分析师       7461     2000人以上          企业服务
# 15     6882983       产品运营（偏数据分析）       7461     2000人以上          企业服务
# 16     6486988       资深数据分析师（杭州）       7461     2000人以上          企业服务
# 17     5519962           大数据建模总监      50735    150-500人            电商
# 18     5559894   数据建模专家-杭州-01546       6502   500-2000人     信息安全,数据服务
# 19     6702852      数据分析专家（游戏业务）        593     2000人以上      移动互联网,游戏
#
#    financeStage                     companyLabelList  firstType secondType  \
# 0            A轮     ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1            B轮     ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2          上市公司     ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3         D轮及以上    ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4          上市公司     ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# 5            B轮     ['股票期权', '扁平管理', '五险一金', '岗位晋升']  产品|需求|项目类       数据分析
# 6            A轮     ['大牛团队', '扁平管理', '年底双薪', '股票期权']  产品|需求|项目类       数据分析
# 7          上市公司     ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 8            A轮  ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  产品|需求|项目类       数据分析
# 9          上市公司     ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 10           A轮  ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  产品|需求|项目类       数据分析
# 11         上市公司     ['技能培训', '年底双薪', '带薪年假', '岗位晋升']  开发|测试|运维类       数据开发
# 12         上市公司     ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 13           A轮  ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  开发|测试|运维类       数据开发
# 14         上市公司   ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  产品|需求|项目类       数据分析
# 15         上市公司   ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  运营|编辑|客服类         运营
# 16         上市公司   ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  开发|测试|运维类       数据开发
# 17           B轮     ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 18        D轮及以上     ['技能培训', '股票期权', '绩效奖金', '岗位晋升']  开发|测试|运维类       数据开发
# 19        不需要融资     ['五险一金', '交通补助', '绩效奖金', '节日礼物']  开发|测试|运维类       数据开发
#
#    thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0       数据分析  ...  NaN      0       0       0              NaN
# 1         建模  ...  NaN      0       0       0              NaN
# 2       数据分析  ...  NaN      0       0       0              NaN
# 3       数据分析  ...  NaN      0       0       0              NaN
# 4       数据分析  ...  NaN      0       0       0              NaN
# 5       数据分析  ...  NaN      0       0       0              NaN
# 6       数据分析  ...  NaN      0       0       0              NaN
# 7         建模  ...  NaN      0       0       0              NaN
# 8     其他数据分析  ...  NaN      0       0       0              NaN
# 9      BI工程师  ...  NaN      0       0       0              NaN
# 10      数据分析  ...  NaN      0       0       0              NaN
# 11      数据分析  ...  NaN      0       0       0              NaN
# 12      数据分析  ...  NaN      0       0       0              NaN
# 13      数据分析  ...  NaN      0       0       0              NaN
# 14      数据分析  ...  NaN      0       0       0              NaN
# 15      数据运营  ...  NaN      0       0       0              NaN
# 16      数据分析  ...  NaN      0       0       0              NaN
# 17        建模  ...  NaN      0       0       0              NaN
# 18        建模  ...  NaN      0       0       0              NaN
# 19      数据分析  ...  NaN      0       0       0              NaN
#
#    promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                    NaN         0      0                   []         False
# 1                    NaN         0      0                   []         False
# 2                    NaN         0      0                   []         False
# 3                    NaN         0      0                   []          True
# 4                    NaN         0      0                   []          True
# 5                    NaN         0      0                   []         False
# 6                    NaN         0      0                   []         False
# 7                    NaN         0      0                   []          True
# 8                    NaN         0      0                   []         False
# 9                    NaN         0      0                   []          True
# 10                   NaN         0      0                   []         False
# 11                   NaN         0      0                   []         False
# 12                   NaN         0      0                   []          True
# 13                   NaN         0      0                   []         False
# 14                   NaN         0      0                   []          True
# 15                   NaN         0      0                   []          True
# 16                   NaN         0      0                   []          True
# 17                   NaN         0      0                   []         False
# 18                   NaN         0      0                   []         False
# 19                   NaN         0      0                   []          True
#
# [20 rows x 52 columns]

# %% [markdown]
# ### 4 读取 Excel 文件｜指定行（跳过）
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件并<font color = '#5F5FFC'>跳过前 20 行</font>

# %%
pd.read_csv("./某招聘网站数据.csv", skiprows=20)
# Out:
#     6702852           数据分析专家（游戏业务）     593    2000人以上     移动互联网,游戏  不需要融资  \
# 0   6829277                资深数据分析师     593    2000人以上     移动互联网,游戏  不需要融资
# 1   6267370                 数据分析专家   31544   150-500人         数据服务  不需要融资
# 2   5927901                 数据分析经理      62    2000人以上        文娱丨内容     C轮
# 3   6862245                 数据分析专家  473950    50-150人        移动互联网    未融资
# 4   5604926                  数据分析师  143884    50-150人     移动互联网,金融     A轮
# ..      ...                    ...     ...        ...          ...    ...
# 80  6884346                  数据分析师   21236  500-2000人  移动互联网,医疗丨健康     C轮
# 81  6849100                 商业数据分析   72076  500-2000人     移动互联网,电商     C轮
# 82  6803432        奔驰·耀出行-BI数据分析专家  751158   150-500人        移动互联网  不需要融资
# 83  6704835                BI数据分析师   52840    2000人以上           电商   上市公司
# 84  6728058  数据分析专家-LQ(J181203029)    2474    2000人以上        汽车丨出行  不需要融资
#
#         ['五险一金', '交通补助', '绩效奖金', '节日礼物']  开发|测试|运维类    数据开发    数据分析  ...  \
# 0       ['五险一金', '交通补助', '绩效奖金', '节日礼物']  产品|需求|项目类  高端产品职位  数据分析专家  ...
# 1     ['专业红娘牵线', '节日礼物', '技能培训', '岗位晋升']  开发|测试|运维类    数据开发    数据分析  ...
# 2   ['扁平管理', '弹性工作', '大厨定制三餐', '就近租房补贴']  产品|需求|项目类    产品经理  其他产品经理  ...
# 3                                     []  产品|需求|项目类    数据分析    数据分析  ...
# 4       ['股票期权', '带薪年假', '绩效奖金', '年底双薪']  开发|测试|运维类    数据开发    数据分析  ...
# ..                                   ...        ...     ...     ...  ...
# 80      ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类    数据分析    数据分析  ...
# 81      ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类   市场|营销  商业数据分析  ...
# 82                                    []  开发|测试|运维类    数据开发    数据分析  ...
# 83      ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类    数据开发    数据分析  ...
# 84      ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类    数据分析  其他数据分析  ...
#
#    Unnamed: 42 0.3 0.4 0.5 Unnamed: 46 Unnamed: 47 0.6  0.7  []   TRUE
# 0          NaN   0   0   0         NaN         NaN   0    0  []   True
# 1          NaN   0   0   0         NaN         NaN   0    0  []  False
# 2          NaN   0   0   0         NaN         NaN   0    0  []   True
# 3          NaN   0   0   0         NaN         NaN   0    0  []  False
# 4          NaN   0   0   0         NaN         NaN   0    0  []  False
# ..         ...  ..  ..  ..         ...         ...  ..  ...  ..    ...
# 80         NaN   0   0   0         NaN         NaN   0    0  []  False
# 81         NaN   0   0   0         NaN         NaN   0    0  []  False
# 82         NaN   0   0   0         NaN         NaN   0    0  []  False
# 83         NaN   0   0   0         NaN         NaN   0    0  []   True
# 84         NaN   0   0   0         NaN         NaN   0    0  []   True
#
# [85 rows x 52 columns]

# %% [markdown]
# ### 5 读取 Excel 文件｜指定行（条件）
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件中全部<font color = '#5F5FFC'>偶数行</font>
#
# 思考：如果是读取全部奇数行，或者更多满足指定条件的行呢？

# %%
pd.read_csv("./某招聘网站数据.csv", skiprows=lambda x: x % 2 != 0)
# Out:
#     positionId         positionName  companyId companySize industryField  \
# 0      5204912                 数据建模      50735    150-500人            电商
# 1      6496141                 数据分析      26564   500-2000人            电商
# 2      6882347                 数据分析      94826     50-150人      移动互联网,社交
# 3      6764018              数据建模工程师      13163   500-2000人         移动互联网
# 4      6786904                数据分析师      13163   500-2000人         移动互联网
# 5      6847013     大数据分析工程师(J11108)      55046     2000人以上    移动互联网,企业服务
# 6      6804489              资深数据分析师      34132    150-500人     数据服务,广告营销
# 7      6882983          产品运营（偏数据分析）       7461     2000人以上          企业服务
# 8      5519962              大数据建模总监      50735    150-500人            电商
# 9      6702852         数据分析专家（游戏业务）        593     2000人以上      移动互联网,游戏
# 10     6267370               数据分析专家      31544    150-500人          数据服务
# 11     6862245               数据分析专家     473950     50-150人         移动互联网
# 12     6601086                数据分析师      21187    150-500人    企业服务,移动互联网
# 13     5520623               数据分析经理      19875     2000人以上            硬件
# 14     6234992                数据分析师        542   500-2000人          消费生活
# 15     6758467              店铺数据分析师      80863    150-500人      移动互联网,电商
# 16     6764017            数据分析师（社招）      13163   500-2000人         移动互联网
# 17     6284662              bi数据分析师      50354     2000人以上         物流丨运输
# 18     6242470                数据分析师      31544    150-500人          数据服务
# 19     6569491                数据分析师     231698     50-150人    移动互联网,数据服务
# 20     6869123          数据分析师（财务方向）     173746    150-500人          消费生活
# 21     5921220              财务数据分析师     137388    150-500人      移动互联网,电商
# 22     6684619              金融数据分析师      26564   500-2000人            电商
# 23     6339988             数据分析师/BI     238706    150-500人      电商,移动互联网
# 24     5990647            高级财务数据分析师      18655     2000人以上         汽车丨出行
# 25     6191993      数据分析专家03-10-217      18655     2000人以上         汽车丨出行
# 26     6814233                数据分析师     619746     2000人以上            教育
# 27     6791055              高级数据分析师     432882    150-500人         移动互联网
# 28     6872125                数据分析师     172552   500-2000人          消费生活
# 29     5453691              数据分析实习生     166666    150-500人     企业服务,数据服务
# 30     5990647            高级财务数据分析师      18655     2000人以上         汽车丨出行
# 31     6680900     数据分析师 (MJ000250)     114335    150-500人          数据服务
# 32     6486069         解决方案顾问/数据分析师     166666    150-500人     企业服务,数据服务
# 33     5203054              资深数据分析师        329     2000人以上            电商
# 34     6116460  资深数据分析/数据分析专家G00796     179243   500-2000人      电商,移动互联网
# 35     6793844              BI数据分析师     555182     50-150人      移动互联网,电商
# 36     6819289                数据分析师      28103     2000人以上       消费生活,硬件
# 37     6698172                数据分析师       2900   500-2000人            电商
# 38     6854920        数据分析师(J10147)     343064     2000人以上            电商
# 39     6046866                数据分析师     543802      15-50人          数据服务
# 40     6602399      商业数据分析师（阿里数据银行）     100858     50-150人    移动互联网,广告营销
# 41     6872841              资深数据分析师        329     2000人以上            电商
# 42     6792091              高级数据分析师      23252   500-2000人         移动互联网
# 43     6095231       数据分析师-企业SaaS应用         62     2000人以上         文娱丨内容
# 44     6655791                 数据分析     289890   500-2000人            其他
# 45     6888169        奔驰耀出行-战略数据分析师     751158    150-500人         移动互联网
# 46     6785139                数据分析师     665061     50-150人          企业服务
# 47     5269002              数据建模工程师      50576    150-500人      移动互联网,游戏
# 48     6718750         旅游大数据分析师（杭州）     122019     50-150人     数据服务,企业服务
# 49     6677939        数据分析建模工程师（校招）  117422215     50-150人     数据服务,信息安全
# 50     6849100               商业数据分析      72076   500-2000人      移动互联网,电商
# 51     6704835              BI数据分析师      52840     2000人以上            电商
#
#    financeStage                      companyLabelList  firstType secondType  \
# 0            B轮      ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 1         D轮及以上     ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 2            B轮      ['股票期权', '扁平管理', '五险一金', '岗位晋升']  产品|需求|项目类       数据分析
# 3          上市公司      ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 4          上市公司      ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 5          上市公司      ['技能培训', '年底双薪', '带薪年假', '岗位晋升']  开发|测试|运维类       数据开发
# 6            A轮   ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  开发|测试|运维类       数据开发
# 7          上市公司    ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  运营|编辑|客服类         运营
# 8            B轮      ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 9         不需要融资      ['五险一金', '交通补助', '绩效奖金', '节日礼物']  开发|测试|运维类       数据开发
# 10        不需要融资    ['专业红娘牵线', '节日礼物', '技能培训', '岗位晋升']  开发|测试|运维类       数据开发
# 11          未融资                                    []  产品|需求|项目类       数据分析
# 12          天使轮       ['带薪年假', '年轻团队', '股票期权', '下午茶']  产品|需求|项目类       数据分析
# 13        不需要融资      ['年终分红', '带薪年假', '年度旅游', '岗位晋升']  产品|需求|项目类       数据分析
# 14        D轮及以上      ['六险一金', '快乐高效文化', '绩效奖金', '信任']  产品|需求|项目类       数据分析
# 15           B轮      ['技能培训', '带薪年假', '绩效奖金', '岗位晋升']     市场|商务类      市场|营销
# 16         上市公司      ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  产品|需求|项目类       数据分析
# 17        D轮及以上      ['技能培训', '节日礼物', '年底双薪', '带薪年假']  开发|测试|运维类       数据开发
# 18        不需要融资    ['专业红娘牵线', '节日礼物', '技能培训', '岗位晋升']  产品|需求|项目类       数据分析
# 19        不需要融资      ['年底双薪', '定期体检', '午餐补助', '交通补助']  产品|需求|项目类       数据分析
# 20           C轮                                    []  产品|需求|项目类       数据分析
# 21        不需要融资      ['年终分红', '绩效奖金', '定期体检', '年底双薪']  综合职能|高级管理         财务
# 22        D轮及以上     ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 23        不需要融资      ['年底双薪', '绩效奖金', '带薪年假', '定期体检']  开发|测试|运维类       数据开发
# 24        D轮及以上        ['技能培训', 'Geek', '开放', '扁平管理']  综合职能|高级管理         财务
# 25        D轮及以上        ['技能培训', 'Geek', '开放', '扁平管理']  开发|测试|运维类       数据开发
# 26         上市公司      ['绩效奖金', '定期体检', '提供宿舍', '管理规范']  产品|需求|项目类       数据分析
# 27        不需要融资    ['技术大牛', '领导nice', '帅哥美女', '环境超棒']  产品|需求|项目类       数据分析
# 28        不需要融资                                    []  产品|需求|项目类       数据分析
# 29           B轮      ['股票期权', '绩效奖金', '带薪年假', '弹性工作']  开发|测试|运维类       数据开发
# 30        D轮及以上        ['技能培训', 'Geek', '开放', '扁平管理']  综合职能|高级管理         财务
# 31           B轮       ['股票期权', '弹性工作', '领导好', '五险一金']  产品|需求|项目类       产品经理
# 32           B轮      ['股票期权', '绩效奖金', '带薪年假', '弹性工作']  产品|需求|项目类       数据分析
# 33         上市公司      ['节日礼物', '技能培训', '免费班车', '带薪年假']  产品|需求|项目类       数据分析
# 34         上市公司      ['绩效奖金', '股票期权', '五险一金', '午餐补助']  开发|测试|运维类       数据开发
# 35          天使轮                                    []  运营|编辑|客服类         运营
# 36         上市公司    ['定期体检', '五险一金', '专项奖金', '骨干家庭公寓']  产品|需求|项目类       数据分析
# 37           C轮      ['扁平化管理', '技术驱动', '14薪', '六险一金']  产品|需求|项目类       数据分析
# 38        不需要融资      ['绩效奖金', '交通补助', '带薪年假', '定期体检']  产品|需求|项目类       产品经理
# 39        不需要融资                                    []  产品|需求|项目类       数据分析
# 40          天使轮      ['节日礼物', '带薪年假', '绩效奖金', '五险一金']     市场|商务类      市场|营销
# 41         上市公司      ['节日礼物', '技能培训', '免费班车', '带薪年假']  开发|测试|运维类       数据开发
# 42         上市公司  ['包午餐晚餐', '奖金多多多', '零食下午茶', '全员出国游']  产品|需求|项目类       数据分析
# 43           C轮  ['扁平管理', '弹性工作', '大厨定制三餐', '就近租房补贴']  产品|需求|项目类       数据分析
# 44          未融资                                    []  产品|需求|项目类       数据分析
# 45        不需要融资                                    []  产品|需求|项目类       数据分析
# 46           B轮                                    []  开发|测试|运维类       数据开发
# 47           A轮        ['带薪年假', '五险一金', '双休', '午餐补助']  开发|测试|运维类       数据开发
# 48           A轮      ['年底双薪', '股票期权', '午餐补助', '定期体检']  开发|测试|运维类       数据开发
# 49           A轮   ['午餐补助', '带薪年假', '16到18薪', '法定节假日']  开发|测试|运维类       人工智能
# 50           C轮      ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 51         上市公司      ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
#
#    thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0         建模  ...  NaN      0       0       0              NaN
# 1       数据分析  ...  NaN      0       0       0              NaN
# 2       数据分析  ...  NaN      0       0       0              NaN
# 3         建模  ...  NaN      0       0       0              NaN
# 4      BI工程师  ...  NaN      0       0       0              NaN
# 5       数据分析  ...  NaN      0       0       0              NaN
# 6       数据分析  ...  NaN      0       0       0              NaN
# 7       数据运营  ...  NaN      0       0       0              NaN
# 8         建模  ...  NaN      0       0       0              NaN
# 9       数据分析  ...  NaN      0       0       0              NaN
# 10      数据分析  ...  NaN      0       0       0              NaN
# 11      数据分析  ...  NaN      0       0       0              NaN
# 12      数据分析  ...  NaN      0       0       0              NaN
# 13      数据分析  ...  NaN      0       0       0              NaN
# 14      数据分析  ...  NaN      0       0       0              NaN
# 15    商业数据分析  ...  NaN      0       0       0              NaN
# 16      数据分析  ...  NaN      0       0       0              NaN
# 17     BI工程师  ...  NaN      0       0       0              NaN
# 18      数据分析  ...  NaN      0       0       0              NaN
# 19      数据分析  ...  NaN      0       0       0              NaN
# 20      数据分析  ...  NaN      0       0       0              NaN
# 21      财务风控  ...  NaN      0       0       0              NaN
# 22      数据分析  ...  NaN      0       0       0              NaN
# 23      数据分析  ...  NaN      0       0       0              NaN
# 24        财务  ...  NaN      0       0       0              NaN
# 25      数据分析  ...  NaN      0       0       0              NaN
# 26      数据分析  ...  NaN      0       0       0              NaN
# 27      数据分析  ...  NaN      0       0       0              NaN
# 28      数据分析  ...  NaN      0       0       0              NaN
# 29      数据分析  ...  NaN      0       0       0              NaN
# 30        财务  ...  NaN      0       0       0              NaN
# 31     数据分析师  ...  NaN      0       0       0              NaN
# 32      数据分析  ...  NaN      0       0       0              NaN
# 33      数据分析  ...  NaN      0       0       0              NaN
# 34      数据分析  ...  NaN      0       0       0              NaN
# 35        运营  ...  NaN      0       0       0              NaN
# 36      数据分析  ...  NaN      0       0       0              NaN
# 37      数据分析  ...  NaN      0       0       0              NaN
# 38     数据分析师  ...  NaN      0       0       0              NaN
# 39      数据分析  ...  NaN      0       0       0              NaN
# 40    商业数据分析  ...  NaN      0       0       0              NaN
# 41      数据分析  ...  NaN      0       0       0              NaN
# 42      数据分析  ...  NaN      0       0       0              NaN
# 43    其他数据分析  ...  NaN      0       0       0              NaN
# 44      数据分析  ...  NaN      0       0       0              NaN
# 45      数据分析  ...  NaN      0       0       0              NaN
# 46      数据分析  ...  NaN      0       0       0              NaN
# 47        建模  ...  NaN      0       0       0              NaN
# 48      数据治理  ...  NaN      0       0       0              NaN
# 49     算法工程师  ...  NaN      0       0       0              NaN
# 50    商业数据分析  ...  NaN      0       0       0              NaN
# 51      数据分析  ...  NaN      0       0       0              NaN
#
#    promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                    NaN         0      0                   []         False
# 1                    NaN         0      0                   []          True
# 2                    NaN         0      0                   []         False
# 3                    NaN         0      0                   []          True
# 4                    NaN         0      0                   []          True
# 5                    NaN         0      0                   []         False
# 6                    NaN         0      0                   []         False
# 7                    NaN         0      0                   []          True
# 8                    NaN         0      0                   []         False
# 9                    NaN         0      0                   []          True
# 10                   NaN         0      0                   []         False
# 11                   NaN         0      0                   []         False
# 12                   NaN         0      0                   []         False
# 13                   NaN         0      0                   []          True
# 14                   NaN         0      0                   []          True
# 15                   NaN         0      0                   []         False
# 16                   NaN         0      0                   []          True
# 17                   NaN         0      0                   []         False
# 18                   NaN         0      0                   []         False
# 19                   NaN         0      0                   []         False
# 20                   NaN         0      0                   []         False
# 21                   NaN         0      0                   []         False
# 22                   NaN         0      0                   []          True
# 23                   NaN         0      0                   []         False
# 24                   NaN         0      0                   []          True
# 25                   NaN         0      0                   []          True
# 26                   NaN         0      0                   []         False
# 27                   NaN         0      0                   []         False
# 28                   NaN         0      0                   []         False
# 29                   NaN         0      0                   []         False
# 30                   NaN         0      0                   []          True
# 31                   NaN         0      0                   []         False
# 32                   NaN         0      0                   []         False
# 33                   NaN         0      0                   []          True
# 34                   NaN         0      0                   []          True
# 35                   NaN         0      0                   []         False
# 36                   NaN         0      0                   []          True
# 37                   NaN         0      0                   []          True
# 38                   NaN         0      0                   []         False
# 39                   NaN         0      0                   []         False
# 40                   NaN         0      0                   []         False
# 41                   NaN         0      0                   []          True
# 42                   NaN         0      0                   []         False
# 43                   NaN         0      0                   []          True
# 44                   NaN         0      0                   []         False
# 45                   NaN         0      0                   []         False
# 46                   NaN         0      0                   []         False
# 47                   NaN         0      0                   []         False
# 48                   NaN         0      0                   []         False
# 49                   NaN         0      0                   []         False
# 50                   NaN         0      0                   []         False
# 51                   NaN         0      0                   []          True
#
# [52 rows x 52 columns]

# %% [markdown]
# ### 6 读取 Excel 文件｜指定列（列号）
#
# <br>
#
# **根据指定列号读取**
#
# 读取当前目录下 `某招聘网站数据.csv` 文件的第 `1、3、5` 列

# %%
df = pd.read_csv("./某招聘网站数据.csv")

# 1,3,5索引
df.iloc[[0, 2, 4]]
# Out:
#    positionId positionName  companyId companySize industryField financeStage  \
# 0     6802721         数据分析     475770     50-150人      移动互联网,电商           A轮
# 2     6877668         数据分析     100125     2000人以上    移动互联网,企业服务         上市公司
# 4     6467417         数据分析      29211     2000人以上         物流丨运输         上市公司
#
#                    companyLabelList  firstType secondType thirdType  ... plus  \
# 0  ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析      数据分析  ...  NaN
# 2  ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析      数据分析  ...  NaN
# 4  ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析  ...  NaN
#
#   pcShow appShow deliver gradeDescription promotionScoreExplain isHotHire  \
# 0      0       0       0              NaN                   NaN         0
# 2      0       0       0              NaN                   NaN         0
# 4      0       0       0              NaN                   NaN         0
#
#    count aggregatePositionIds famousCompany
# 0      0                   []         False
# 2      0                   []         False
# 4      0                   []          True
#
# [3 rows x 52 columns]

# %% [markdown]
# ### 7 读取 Excel 文件｜指定列（列名）
#
# <br>
#
# **根据指定列名读取**
#
# 读取当前目录下 `某招聘网站数据.csv` 文件的 `positionId、positionName、salary` 列

# %%
df = pd.read_csv(
    "./某招聘网站数据.csv", usecols=["positionId", "positionName", "salary"]
)
df
# Out:
#      positionId           positionName  salary
# 0       6802721                   数据分析   37500
# 1       5204912                   数据建模   15000
# 2       6877668                   数据分析    3500
# 3       6496141                   数据分析   45000
# 4       6467417                   数据分析   30000
# ..          ...                    ...     ...
# 100     6884346                  数据分析师   25000
# 101     6849100                 商业数据分析   35000
# 102     6803432        奔驰·耀出行-BI数据分析专家   30000
# 103     6704835                BI数据分析师   20000
# 104     6728058  数据分析专家-LQ(J181203029)   21500
#
# [105 rows x 3 columns]

# %% [markdown]
# ### 8 读取 Excel 文件｜指定列（匹配）
#
# <br>
#
# **根据指定列名匹配读取**
#
# 让我们来个更难一点的，还是读取 `某招聘网站数据.csv` 文件，但现在有一个 list 中包含多个字段 👇
#
# `usecols = ['positionId','test','positionName', 'test1','salary']`
#
# 如果 `usecols` 中的列名存在于 `某招聘网站数据.csv` 中，则读取。

# %%
usecols = ["positionId", "test", "positionName", "test1", "salary"]
pd.read_csv(
    "./某招聘网站数据.csv",
    usecols=lambda col: col in usecols,
)
# Out:
#      positionId           positionName  salary
# 0       6802721                   数据分析   37500
# 1       5204912                   数据建模   15000
# 2       6877668                   数据分析    3500
# 3       6496141                   数据分析   45000
# 4       6467417                   数据分析   30000
# ..          ...                    ...     ...
# 100     6884346                  数据分析师   25000
# 101     6849100                 商业数据分析   35000
# 102     6803432        奔驰·耀出行-BI数据分析专家   30000
# 103     6704835                BI数据分析师   20000
# 104     6728058  数据分析专家-LQ(J181203029)   21500
#
# [105 rows x 3 columns]

# %% [markdown]
# ### 9 读取 Excel 文件｜指定索引
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，并在读取时将 `positionId` 设置为索引列

# %%
pd.read_csv("./某招聘网站数据.csv", index_col="positionId")
# Out:
#                      positionName  companyId companySize industryField  \
# positionId
# 6802721                      数据分析     475770     50-150人      移动互联网,电商
# 5204912                      数据建模      50735    150-500人            电商
# 6877668                      数据分析     100125     2000人以上    移动互联网,企业服务
# 6496141                      数据分析      26564   500-2000人            电商
# 6467417                      数据分析      29211     2000人以上         物流丨运输
# ...                           ...        ...         ...           ...
# 6884346                     数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 6849100                    商业数据分析      72076   500-2000人      移动互联网,电商
# 6803432           奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 6704835                   BI数据分析师      52840     2000人以上            电商
# 6728058     数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#            financeStage                   companyLabelList  firstType  \
# positionId
# 6802721              A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类
# 5204912              B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类
# 6877668            上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类
# 6496141           D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类
# 6467417            上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类
# ...                 ...                                ...        ...
# 6884346              C轮   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类
# 6849100              C轮   ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类
# 6803432           不需要融资                                 []  开发|测试|运维类
# 6704835            上市公司   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类
# 6728058           不需要融资   ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类
#
#            secondType thirdType                     skillLables  ... plus  \
# positionId                                                       ...
# 6802721          数据分析      数据分析    ['SQL', '数据库', '数据运营', 'BI']  ...  NaN
# 5204912          数据开发        建模                  ['算法', '数据架构']  ...  NaN
# 6877668          数据分析      数据分析          ['数据库', '数据分析', 'SQL']  ...  NaN
# 6496141          数据开发      数据分析                              []  ...  NaN
# 6467417          数据分析      数据分析          ['BI', '数据分析', '数据运营']  ...  NaN
# ...               ...       ...                             ...  ...  ...
# 6884346          数据分析      数据分析    ['数据库', '商业', '数据分析', 'SQL']  ...  NaN
# 6849100         市场|营销    商业数据分析  ['市场', '数据分析', '行业分析', '市场分析']  ...  NaN
# 6803432          数据开发      数据分析       ['MySQL', '数据处理', '数据分析']  ...  NaN
# 6704835          数据开发      数据分析           ['SQLServer', '数据分析']  ...  NaN
# 6728058          数据分析    其他数据分析                              []  ...  NaN
#
#            pcShow appShow deliver gradeDescription promotionScoreExplain  \
# positionId
# 6802721         0       0       0              NaN                   NaN
# 5204912         0       0       0              NaN                   NaN
# 6877668         0       0       0              NaN                   NaN
# 6496141         0       0       0              NaN                   NaN
# 6467417         0       0       0              NaN                   NaN
# ...           ...     ...     ...              ...                   ...
# 6884346         0       0       0              NaN                   NaN
# 6849100         0       0       0              NaN                   NaN
# 6803432         0       0       0              NaN                   NaN
# 6704835         0       0       0              NaN                   NaN
# 6728058         0       0       0              NaN                   NaN
#
#             isHotHire count aggregatePositionIds famousCompany
# positionId
# 6802721             0     0                   []         False
# 5204912             0     0                   []         False
# 6877668             0     0                   []         False
# 6496141             0     0                   []          True
# 6467417             0     0                   []          True
# ...               ...   ...                  ...           ...
# 6884346             0     0                   []         False
# 6849100             0     0                   []         False
# 6803432             0     0                   []         False
# 6704835             0     0                   []          True
# 6728058             0     0                   []          True
#
# [105 rows x 51 columns]

# %% [markdown]
# ### 10 读取 Excel 文件｜指定标题
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件的 `positionId、positionName、salary` 列，并将标题设置为 `ID、岗位名称、薪资`

# %%
df = pd.read_csv(
    "./某招聘网站数据.csv",
    usecols=["positionId", "positionName", "salary"],
)
df.rename(columns={"positionId": "ID", "positionName": "岗位名称", "salary": "薪资"})
# Out:
#           ID                   岗位名称     薪资
# 0    6802721                   数据分析  37500
# 1    5204912                   数据建模  15000
# 2    6877668                   数据分析   3500
# 3    6496141                   数据分析  45000
# 4    6467417                   数据分析  30000
# ..       ...                    ...    ...
# 100  6884346                  数据分析师  25000
# 101  6849100                 商业数据分析  35000
# 102  6803432        奔驰·耀出行-BI数据分析专家  30000
# 103  6704835                BI数据分析师  20000
# 104  6728058  数据分析专家-LQ(J181203029)  21500
#
# [105 rows x 3 columns]

# %% [markdown]
# ### 11 读取 Excel 文件｜缺失值转换
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，**并不将缺失值标记为 `NA`**
#
# 思考：为什么要这样做？

# %%
pd.read_csv("./某招聘网站数据.csv", na_filter=False)
# Out:
#      positionId           positionName  companyId companySize industryField  \
# 0       6802721                   数据分析     475770     50-150人      移动互联网,电商
# 1       5204912                   数据建模      50735    150-500人            电商
# 2       6877668                   数据分析     100125     2000人以上    移动互联网,企业服务
# 3       6496141                   数据分析      26564   500-2000人            电商
# 4       6467417                   数据分析      29211     2000人以上         物流丨运输
# ..          ...                    ...        ...         ...           ...
# 100     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 101     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#     financeStage                   companyLabelList  firstType secondType  \
# 0             A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1             B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2           上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3          D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4           上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# ..           ...                                ...        ...        ...
# 100           C轮   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 101           C轮   ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 102        不需要融资                                 []  开发|测试|运维类       数据开发
# 103         上市公司   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 104        不需要融资   ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#     thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0        数据分析  ...           0       0       0
# 1          建模  ...           0       0       0
# 2        数据分析  ...           0       0       0
# 3        数据分析  ...           0       0       0
# 4        数据分析  ...           0       0       0
# ..        ...  ...  ...    ...     ...     ...              ...
# 100      数据分析  ...           0       0       0
# 101    商业数据分析  ...           0       0       0
# 102      数据分析  ...           0       0       0
# 103      数据分析  ...           0       0       0
# 104    其他数据分析  ...           0       0       0
#
#     promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                                 0      0                   []         False
# 1                                 0      0                   []         False
# 2                                 0      0                   []         False
# 3                                 0      0                   []          True
# 4                                 0      0                   []          True
# ..                    ...       ...    ...                  ...           ...
# 100                               0      0                   []         False
# 101                               0      0                   []         False
# 102                               0      0                   []         False
# 103                               0      0                   []          True
# 104                               0      0                   []          True
#
# [105 rows x 52 columns]

# %% [markdown]
# ### 12 读取 Excel 文件｜缺失值标记
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，**并将`[]`标记为缺失值**

# %%
pd.read_csv('./某招聘网站数据.csv', na_values=["[]"])
# Out:
#      positionId           positionName  companyId companySize industryField  \
# 0       6802721                   数据分析     475770     50-150人      移动互联网,电商
# 1       5204912                   数据建模      50735    150-500人            电商
# 2       6877668                   数据分析     100125     2000人以上    移动互联网,企业服务
# 3       6496141                   数据分析      26564   500-2000人            电商
# 4       6467417                   数据分析      29211     2000人以上         物流丨运输
# ..          ...                    ...        ...         ...           ...
# 100     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 101     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#     financeStage                   companyLabelList  firstType secondType  \
# 0             A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1             B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2           上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3          D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4           上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# ..           ...                                ...        ...        ...
# 100           C轮   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 101           C轮   ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 102        不需要融资                                NaN  开发|测试|运维类       数据开发
# 103         上市公司   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 104        不需要融资   ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#     thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0        数据分析  ...  NaN      0       0       0              NaN
# 1          建模  ...  NaN      0       0       0              NaN
# 2        数据分析  ...  NaN      0       0       0              NaN
# 3        数据分析  ...  NaN      0       0       0              NaN
# 4        数据分析  ...  NaN      0       0       0              NaN
# ..        ...  ...  ...    ...     ...     ...              ...
# 100      数据分析  ...  NaN      0       0       0              NaN
# 101    商业数据分析  ...  NaN      0       0       0              NaN
# 102      数据分析  ...  NaN      0       0       0              NaN
# 103      数据分析  ...  NaN      0       0       0              NaN
# 104    其他数据分析  ...  NaN      0       0       0              NaN
#
#     promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                     NaN         0      0                  NaN         False
# 1                     NaN         0      0                  NaN         False
# 2                     NaN         0      0                  NaN         False
# 3                     NaN         0      0                  NaN          True
# 4                     NaN         0      0                  NaN          True
# ..                    ...       ...    ...                  ...           ...
# 100                   NaN         0      0                  NaN         False
# 101                   NaN         0      0                  NaN         False
# 102                   NaN         0      0                  NaN         False
# 103                   NaN         0      0                  NaN          True
# 104                   NaN         0      0                  NaN          True
#
# [105 rows x 52 columns]

# %% [markdown]
# ### 13 读取 Excel 文件｜忽略缺失值
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，**但不处理缺失值**
#
# 思考：和之前的有什么不同，为什么这么做？

# %%
pd.read_csv("./某招聘网站数据.csv")
# Out:
#      positionId           positionName  companyId companySize industryField  \
# 0       6802721                   数据分析     475770     50-150人      移动互联网,电商
# 1       5204912                   数据建模      50735    150-500人            电商
# 2       6877668                   数据分析     100125     2000人以上    移动互联网,企业服务
# 3       6496141                   数据分析      26564   500-2000人            电商
# 4       6467417                   数据分析      29211     2000人以上         物流丨运输
# ..          ...                    ...        ...         ...           ...
# 100     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 101     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#     financeStage                   companyLabelList  firstType secondType  \
# 0             A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1             B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2           上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3          D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4           上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# ..           ...                                ...        ...        ...
# 100           C轮   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 101           C轮   ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 102        不需要融资                                 []  开发|测试|运维类       数据开发
# 103         上市公司   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 104        不需要融资   ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#     thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0        数据分析  ...  NaN      0       0       0              NaN
# 1          建模  ...  NaN      0       0       0              NaN
# 2        数据分析  ...  NaN      0       0       0              NaN
# 3        数据分析  ...  NaN      0       0       0              NaN
# 4        数据分析  ...  NaN      0       0       0              NaN
# ..        ...  ...  ...    ...     ...     ...              ...
# 100      数据分析  ...  NaN      0       0       0              NaN
# 101    商业数据分析  ...  NaN      0       0       0              NaN
# 102      数据分析  ...  NaN      0       0       0              NaN
# 103      数据分析  ...  NaN      0       0       0              NaN
# 104    其他数据分析  ...  NaN      0       0       0              NaN
#
#     promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                     NaN         0      0                   []         False
# 1                     NaN         0      0                   []         False
# 2                     NaN         0      0                   []         False
# 3                     NaN         0      0                   []          True
# 4                     NaN         0      0                   []          True
# ..                    ...       ...    ...                  ...           ...
# 100                   NaN         0      0                   []         False
# 101                   NaN         0      0                   []         False
# 102                   NaN         0      0                   []         False
# 103                   NaN         0      0                   []          True
# 104                   NaN         0      0                   []          True
#
# [105 rows x 52 columns]

# %% [markdown]
# ### 14 读取 Excel 文件｜指定格式
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，并将 `positionId,companyId` 设置为字符串格式

# %%
df = pd.read_csv("./某招聘网站数据.csv", dtype={"positionId": str, "companyId": str})
df.dtypes
# Out:
# positionId                object
# positionName              object
# companyId                 object
# companySize               object
# industryField             object
# financeStage              object
# companyLabelList          object
# firstType                 object
# secondType                object
# thirdType                 object
# skillLables               object
# positionLables            object
# industryLables            object
# createTime                object
# formatCreateTime          object
# district                  object
# businessZones             object
# salary                     int64
# workYear                  object
# jobNature                 object
# education                 object
# positionAdvantage         object
# imState                   object
# lastLogin                 object
# publisherId                int64
# approve                    int64
# subwayline                object
# stationname               object
# linestaion                object
# latitude                 float64
# longitude                float64
# hitags                    object
# resumeProcessRate          int64
# resumeProcessDay           int64
# score                      int64
# newScore                   int64
# matchScore               float64
# matchScoreExplain        float64
# query                    float64
# explain                  float64
# isSchoolJob                int64
# adWord                     int64
# plus                     float64
# pcShow                     int64
# appShow                    int64
# deliver                    int64
# gradeDescription         float64
# promotionScoreExplain    float64
# isHotHire                  int64
# count                      int64
# aggregatePositionIds      object
# famousCompany               bool
# dtype: object

# %% [markdown]
# ### 15 读取 Excel 文件｜指定格式（时间）
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，并将 `createTime` 列设置为字符串格式

# %%
pd.read_csv('./某招聘网站数据.csv', dtype={'createTime': str})
# Out:
#      positionId           positionName  companyId companySize industryField  \
# 0       6802721                   数据分析     475770     50-150人      移动互联网,电商
# 1       5204912                   数据建模      50735    150-500人            电商
# 2       6877668                   数据分析     100125     2000人以上    移动互联网,企业服务
# 3       6496141                   数据分析      26564   500-2000人            电商
# 4       6467417                   数据分析      29211     2000人以上         物流丨运输
# ..          ...                    ...        ...         ...           ...
# 100     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 101     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#     financeStage                   companyLabelList  firstType secondType  \
# 0             A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1             B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2           上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3          D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4           上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# ..           ...                                ...        ...        ...
# 100           C轮   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 101           C轮   ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 102        不需要融资                                 []  开发|测试|运维类       数据开发
# 103         上市公司   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 104        不需要融资   ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#     thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0        数据分析  ...  NaN      0       0       0              NaN
# 1          建模  ...  NaN      0       0       0              NaN
# 2        数据分析  ...  NaN      0       0       0              NaN
# 3        数据分析  ...  NaN      0       0       0              NaN
# 4        数据分析  ...  NaN      0       0       0              NaN
# ..        ...  ...  ...    ...     ...     ...              ...
# 100      数据分析  ...  NaN      0       0       0              NaN
# 101    商业数据分析  ...  NaN      0       0       0              NaN
# 102      数据分析  ...  NaN      0       0       0              NaN
# 103      数据分析  ...  NaN      0       0       0              NaN
# 104    其他数据分析  ...  NaN      0       0       0              NaN
#
#     promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                     NaN         0      0                   []         False
# 1                     NaN         0      0                   []         False
# 2                     NaN         0      0                   []         False
# 3                     NaN         0      0                   []          True
# 4                     NaN         0      0                   []          True
# ..                    ...       ...    ...                  ...           ...
# 100                   NaN         0      0                   []         False
# 101                   NaN         0      0                   []         False
# 102                   NaN         0      0                   []         False
# 103                   NaN         0      0                   []          True
# 104                   NaN         0      0                   []          True
#
# [105 rows x 52 columns]

# %% [markdown]
# ### 16 读取 Excel 文件｜分块读取
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，要求返回一个可迭代对象，每次读取 10 行
#
# 思考：为什么这样做？

# %%
for chunk in pd.read_csv('./某招聘网站数据.csv', chunksize=20):
    print(chunk)
# Out:
#     positionId      positionName  companyId companySize industryField  \
# 0      6802721              数据分析     475770     50-150人      移动互联网,电商
# 1      5204912              数据建模      50735    150-500人            电商
# 2      6877668              数据分析     100125     2000人以上    移动互联网,企业服务
# 3      6496141              数据分析      26564   500-2000人            电商
# 4      6467417              数据分析      29211     2000人以上         物流丨运输
# 5      6882347              数据分析      94826     50-150人      移动互联网,社交
# 6      6841659              数据分析     348784     50-150人      移动互联网,电商
# 7      6764018           数据建模工程师      13163   500-2000人         移动互联网
# 8      6458372            数据分析专家      34132    150-500人     数据服务,广告营销
# 9      6786904             数据分析师      13163   500-2000人         移动互联网
# 10     6804629             数据分析师      34132    150-500人     数据服务,广告营销
# 11     6847013  大数据分析工程师(J11108)      55046     2000人以上    移动互联网,企业服务
# 12     6763962           数据分析工程师      13163   500-2000人         移动互联网
# 13     6804489           资深数据分析师      34132    150-500人     数据服务,广告营销
# 14     6657285             数据分析师       7461     2000人以上          企业服务
# 15     6882983       产品运营（偏数据分析）       7461     2000人以上          企业服务
# 16     6486988       资深数据分析师（杭州）       7461     2000人以上          企业服务
# 17     5519962           大数据建模总监      50735    150-500人            电商
# 18     5559894   数据建模专家-杭州-01546       6502   500-2000人     信息安全,数据服务
# 19     6702852      数据分析专家（游戏业务）        593     2000人以上      移动互联网,游戏
#
#    financeStage                     companyLabelList  firstType secondType  \
# 0            A轮     ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1            B轮     ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2          上市公司     ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3         D轮及以上    ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4          上市公司     ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# 5            B轮     ['股票期权', '扁平管理', '五险一金', '岗位晋升']  产品|需求|项目类       数据分析
# 6            A轮     ['大牛团队', '扁平管理', '年底双薪', '股票期权']  产品|需求|项目类       数据分析
# 7          上市公司     ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 8            A轮  ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  产品|需求|项目类       数据分析
# 9          上市公司     ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 10           A轮  ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  产品|需求|项目类       数据分析
# 11         上市公司     ['技能培训', '年底双薪', '带薪年假', '岗位晋升']  开发|测试|运维类       数据开发
# 12         上市公司     ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 13           A轮  ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  开发|测试|运维类       数据开发
# 14         上市公司   ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  产品|需求|项目类       数据分析
# 15         上市公司   ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  运营|编辑|客服类         运营
# 16         上市公司   ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  开发|测试|运维类       数据开发
# 17           B轮     ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 18        D轮及以上     ['技能培训', '股票期权', '绩效奖金', '岗位晋升']  开发|测试|运维类       数据开发
# 19        不需要融资     ['五险一金', '交通补助', '绩效奖金', '节日礼物']  开发|测试|运维类       数据开发
#
#    thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0       数据分析  ...  NaN      0       0       0              NaN
# 1         建模  ...  NaN      0       0       0              NaN
# 2       数据分析  ...  NaN      0       0       0              NaN
# 3       数据分析  ...  NaN      0       0       0              NaN
# 4       数据分析  ...  NaN      0       0       0              NaN
# 5       数据分析  ...  NaN      0       0       0              NaN
# 6       数据分析  ...  NaN      0       0       0              NaN
# 7         建模  ...  NaN      0       0       0              NaN
# 8     其他数据分析  ...  NaN      0       0       0              NaN
# 9      BI工程师  ...  NaN      0       0       0              NaN
# 10      数据分析  ...  NaN      0       0       0              NaN
# 11      数据分析  ...  NaN      0       0       0              NaN
# 12      数据分析  ...  NaN      0       0       0              NaN
# 13      数据分析  ...  NaN      0       0       0              NaN
# 14      数据分析  ...  NaN      0       0       0              NaN
# 15      数据运营  ...  NaN      0       0       0              NaN
# 16      数据分析  ...  NaN      0       0       0              NaN
# 17        建模  ...  NaN      0       0       0              NaN
# 18        建模  ...  NaN      0       0       0              NaN
# 19      数据分析  ...  NaN      0       0       0              NaN
#
#    promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                    NaN         0      0                   []         False
# 1                    NaN         0      0                   []         False
# 2                    NaN         0      0                   []         False
# 3                    NaN         0      0                   []          True
# 4                    NaN         0      0                   []          True
# 5                    NaN         0      0                   []         False
# 6                    NaN         0      0                   []         False
# 7                    NaN         0      0                   []          True
# 8                    NaN         0      0                   []         False
# 9                    NaN         0      0                   []          True
# 10                   NaN         0      0                   []         False
# 11                   NaN         0      0                   []         False
# 12                   NaN         0      0                   []          True
# 13                   NaN         0      0                   []         False
# 14                   NaN         0      0                   []          True
# 15                   NaN         0      0                   []          True
# 16                   NaN         0      0                   []          True
# 17                   NaN         0      0                   []         False
# 18                   NaN         0      0                   []         False
# 19                   NaN         0      0                   []          True
#
# [20 rows x 52 columns]
#     positionId positionName  companyId companySize industryField financeStage  \
# 20     6829277      资深数据分析师        593     2000人以上      移动互联网,游戏        不需要融资
# 21     6267370       数据分析专家      31544    150-500人          数据服务        不需要融资
# 22     5927901       数据分析经理         62     2000人以上         文娱丨内容           C轮
# 23     6862245       数据分析专家     473950     50-150人         移动互联网          未融资
# 24     5604926        数据分析师     143884     50-150人      移动互联网,金融           A轮
# 25     6601086        数据分析师      21187    150-500人    企业服务,移动互联网          天使轮
# 26     6850849       数据分析专家     255742    150-500人         金融,电商           C轮
# 27     5520623       数据分析经理      19875     2000人以上            硬件        不需要融资
# 28     6657704        数据分析师     165220    150-500人            社交        不需要融资
# 29     6234992        数据分析师        542   500-2000人          消费生活        D轮及以上
# 30     6234992        数据分析师        542   500-2000人          消费生活        D轮及以上
# 31     6758467      店铺数据分析师      80863    150-500人      移动互联网,电商           B轮
# 32     6804489      资深数据分析师      34132    150-500人     数据服务,广告营销           A轮
# 33     6764017    数据分析师（社招）      13163   500-2000人         移动互联网         上市公司
# 34     6228290      商业数据分析师     509360     50-150人    移动互联网,企业服务           B轮
# 35     6284662      bi数据分析师      50354     2000人以上         物流丨运输        D轮及以上
# 36     6886661      浙江数据分析师     321001    150-500人       金融,数据服务        D轮及以上
# 37     6242470        数据分析师      31544    150-500人          数据服务        不需要融资
# 38     6601086        数据分析师      21187    150-500人    企业服务,移动互联网          天使轮
# 39     6569491        数据分析师     231698     50-150人    移动互联网,数据服务        不需要融资
#
#                         companyLabelList  firstType secondType thirdType  ...  \
# 20      ['五险一金', '交通补助', '绩效奖金', '节日礼物']  产品|需求|项目类     高端产品职位    数据分析专家  ...
# 21    ['专业红娘牵线', '节日礼物', '技能培训', '岗位晋升']  开发|测试|运维类       数据开发      数据分析  ...
# 22  ['扁平管理', '弹性工作', '大厨定制三餐', '就近租房补贴']  产品|需求|项目类       产品经理    其他产品经理  ...
# 23                                    []  产品|需求|项目类       数据分析      数据分析  ...
# 24      ['股票期权', '带薪年假', '绩效奖金', '年底双薪']  开发|测试|运维类       数据开发      数据分析  ...
# 25       ['带薪年假', '年轻团队', '股票期权', '下午茶']  产品|需求|项目类       数据分析      数据分析  ...
# 26   ['持牌金融机构', '跨境支付', '跨境金融', '国际化团队']  开发|测试|运维类       数据开发      数据分析  ...
# 27      ['年终分红', '带薪年假', '年度旅游', '岗位晋升']  产品|需求|项目类       数据分析      数据分析  ...
# 28      ['绩效奖金', '带薪年假', '交通补助', '午餐补助']  产品|需求|项目类       数据分析      数据分析  ...
# 29      ['六险一金', '快乐高效文化', '绩效奖金', '信任']  产品|需求|项目类       数据分析      数据分析  ...
# 30      ['六险一金', '快乐高效文化', '绩效奖金', '信任']  产品|需求|项目类       数据分析      数据分析  ...
# 31      ['技能培训', '带薪年假', '绩效奖金', '岗位晋升']     市场|商务类      市场|营销    商业数据分析  ...
# 32   ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  开发|测试|运维类       数据开发      数据分析  ...
# 33      ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  产品|需求|项目类       数据分析      数据分析  ...
# 34         ['定期体检', '帅哥多', '领导好', '美女多']     市场|商务类      市场|营销    商业数据分析  ...
# 35      ['技能培训', '节日礼物', '年底双薪', '带薪年假']  开发|测试|运维类       数据开发     BI工程师  ...
# 36      ['年底双薪', '午餐补助', '年终分红', '绩效奖金']  开发|测试|运维类       数据开发      数据分析  ...
# 37    ['专业红娘牵线', '节日礼物', '技能培训', '岗位晋升']  产品|需求|项目类       数据分析      数据分析  ...
# 38       ['带薪年假', '年轻团队', '股票期权', '下午茶']  产品|需求|项目类       数据分析      数据分析  ...
# 39      ['年底双薪', '定期体检', '午餐补助', '交通补助']  产品|需求|项目类       数据分析      数据分析  ...
#
#    plus pcShow appShow deliver gradeDescription promotionScoreExplain  \
# 20  NaN      0       0       0              NaN                   NaN
# 21  NaN      0       0       0              NaN                   NaN
# 22  NaN      0       0       0              NaN                   NaN
# 23  NaN      0       0       0              NaN                   NaN
# 24  NaN      0       0       0              NaN                   NaN
# 25  NaN      0       0       0              NaN                   NaN
# 26  NaN      0       0       0              NaN                   NaN
# 27  NaN      0       0       0              NaN                   NaN
# 28  NaN      0       0       0              NaN                   NaN
# 29  NaN      0       0       0              NaN                   NaN
# 30  NaN      0       0       0              NaN                   NaN
# 31  NaN      0       0       0              NaN                   NaN
# 32  NaN      0       0       0              NaN                   NaN
# 33  NaN      0       0       0              NaN                   NaN
# 34  NaN      0       0       0              NaN                   NaN
# 35  NaN      0       0       0              NaN                   NaN
# 36  NaN      0       0       0              NaN                   NaN
# 37  NaN      0       0       0              NaN                   NaN
# 38  NaN      0       0       0              NaN                   NaN
# 39  NaN      0       0       0              NaN                   NaN
#
#    isHotHire  count aggregatePositionIds famousCompany
# 20         0      0                   []          True
# 21         0      0                   []         False
# 22         0      0                   []          True
# 23         0      0                   []         False
# 24         0      0                   []         False
# 25         0      0                   []         False
# 26         0      0                   []         False
# 27         0      0                   []          True
# 28         0      0                   []         False
# 29         0      0                   []          True
# 30         0      0                   []          True
# 31         0      0                   []         False
# 32         0      0                   []         False
# 33         0      0                   []          True
# 34         0      0                   []         False
# 35         0      0                   []         False
# 36         0      0                   []         False
# 37         0      0                   []         False
# 38         0      0                   []         False
# 39         0      0                   []         False
#
# [20 rows x 52 columns]
#     positionId        positionName  companyId companySize industryField  \
# 40     6791055             高级数据分析师     432882    150-500人         移动互联网
# 41     6869123         数据分析师（财务方向）     173746    150-500人          消费生活
# 42     6344146             资深数据分析师     522865    150-500人            游戏
# 43     5921220             财务数据分析师     137388    150-500人      移动互联网,电商
# 44     6653757             银行数据分析岗      23403     2000人以上          企业服务
# 45     6684619             金融数据分析师      26564   500-2000人            电商
# 46     6228290             商业数据分析师     509360     50-150人    移动互联网,企业服务
# 47     6339988            数据分析师/BI     238706    150-500人      电商,移动互联网
# 48     6067812              数据分析专员      98316     2000人以上       电商,消费生活
# 49     5990647           高级财务数据分析师      18655     2000人以上         汽车丨出行
# 50     6680900    数据分析师 (MJ000250)     114335    150-500人          数据服务
# 51     6191993     数据分析专家03-10-217      18655     2000人以上         汽车丨出行
# 52     6486069        解决方案顾问/数据分析师     166666    150-500人     企业服务,数据服务
# 53     6814233               数据分析师     619746     2000人以上            教育
# 54     6046775              数据分析专家     133429     50-150人    移动互联网,消费生活
# 55     6791055             高级数据分析师     432882    150-500人         移动互联网
# 56     6037742  资深数据分析师 (MJ000088)     127233    150-500人          电子商务
# 57     6872125               数据分析师     172552   500-2000人          消费生活
# 58     5921220             财务数据分析师     137388    150-500人      移动互联网,电商
# 59     5453691             数据分析实习生     166666    150-500人     企业服务,数据服务
#
#    financeStage                    companyLabelList  firstType secondType  \
# 40        不需要融资  ['技术大牛', '领导nice', '帅哥美女', '环境超棒']  产品|需求|项目类       数据分析
# 41           C轮                                  []  产品|需求|项目类       数据分析
# 42        不需要融资    ['年底双薪', '专项奖金', '提供三餐', '便捷班车']  开发|测试|运维类       数据开发
# 43        不需要融资    ['年终分红', '绩效奖金', '定期体检', '年底双薪']  综合职能|高级管理         财务
# 44         上市公司    ['五险一金', '通讯津贴', '带薪年假', '定期体检']  开发|测试|运维类       数据开发
# 45        D轮及以上   ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 46           B轮       ['定期体检', '帅哥多', '领导好', '美女多']     市场|商务类      市场|营销
# 47        不需要融资    ['年底双薪', '绩效奖金', '带薪年假', '定期体检']  开发|测试|运维类       数据开发
# 48         上市公司    ['午餐补助', '带薪年假', '定期体检', '年度旅游']  产品|需求|项目类       数据分析
# 49        D轮及以上      ['技能培训', 'Geek', '开放', '扁平管理']  综合职能|高级管理         财务
# 50           B轮     ['股票期权', '弹性工作', '领导好', '五险一金']  产品|需求|项目类       产品经理
# 51        D轮及以上      ['技能培训', 'Geek', '开放', '扁平管理']  开发|测试|运维类       数据开发
# 52           B轮    ['股票期权', '绩效奖金', '带薪年假', '弹性工作']  产品|需求|项目类       数据分析
# 53         上市公司    ['绩效奖金', '定期体检', '提供宿舍', '管理规范']  产品|需求|项目类       数据分析
# 54          未融资     ['年底双薪', '专项奖金', '美女多', '弹性工作']  产品|需求|项目类     高端产品职位
# 55        不需要融资  ['技术大牛', '领导nice', '帅哥美女', '环境超棒']  产品|需求|项目类       数据分析
# 56        不需要融资    ['带薪年假', '绩效奖金', '定期体检', '弹性工作']  开发|测试|运维类       数据开发
# 57        不需要融资                                  []  产品|需求|项目类       数据分析
# 58        不需要融资    ['年终分红', '绩效奖金', '定期体检', '年底双薪']  综合职能|高级管理         财务
# 59           B轮    ['股票期权', '绩效奖金', '带薪年假', '弹性工作']  开发|测试|运维类       数据开发
#
#    thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 40      数据分析  ...  NaN      0       0       0              NaN
# 41      数据分析  ...  NaN      0       0       0              NaN
# 42      数据分析  ...  NaN      0       0       0              NaN
# 43      财务风控  ...  NaN      0       0       0              NaN
# 44      数据分析  ...  NaN      0       0       0              NaN
# 45      数据分析  ...  NaN      0       0       0              NaN
# 46    商业数据分析  ...  NaN      0       0       0              NaN
# 47      数据分析  ...  NaN      0       0       0              NaN
# 48      数据分析  ...  NaN      0       0       0              NaN
# 49        财务  ...  NaN      0       0       0              NaN
# 50     数据分析师  ...  NaN      0       0       0              NaN
# 51      数据分析  ...  NaN      0       0       0              NaN
# 52      数据分析  ...  NaN      0       0       0              NaN
# 53      数据分析  ...  NaN      0       0       0              NaN
# 54    数据分析专家  ...  NaN      0       0       0              NaN
# 55      数据分析  ...  NaN      0       0       0              NaN
# 56      数据分析  ...  NaN      0       0       0              NaN
# 57      数据分析  ...  NaN      0       0       0              NaN
# 58      财务风控  ...  NaN      0       0       0              NaN
# 59      数据分析  ...  NaN      0       0       0              NaN
#
#    promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 40                   NaN         0      0                   []         False
# 41                   NaN         0      0                   []         False
# 42                   NaN         0      0                   []         False
# 43                   NaN         0      0                   []         False
# 44                   NaN         0      0                   []         False
# 45                   NaN         0      0                   []          True
# 46                   NaN         0      0                   []         False
# 47                   NaN         0      0                   []         False
# 48                   NaN         0      0                   []         False
# 49                   NaN         0      0                   []          True
# 50                   NaN         0      0                   []         False
# 51                   NaN         0      0                   []          True
# 52                   NaN         0      0                   []         False
# 53                   NaN         0      0                   []         False
# 54                   NaN         0      0                   []         False
# 55                   NaN         0      0                   []         False
# 56                   NaN         0      0                   []         False
# 57                   NaN         0      0                   []         False
# 58                   NaN         0      0                   []         False
# 59                   NaN         0      0                   []         False
#
# [20 rows x 52 columns]
#     positionId         positionName  companyId companySize industryField  \
# 60     5978750    数据分析师（保险）13-01-19      18655     2000人以上         汽车丨出行
# 61     5990647            高级财务数据分析师      18655     2000人以上         汽车丨出行
# 62     6191993      数据分析专家03-10-217      18655     2000人以上         汽车丨出行
# 63     6680900     数据分析师 (MJ000250)     114335    150-500人          数据服务
# 64     6789831              数据分析实习生     306282    150-500人    移动互联网,数据服务
# 65     6486069         解决方案顾问/数据分析师     166666    150-500人     企业服务,数据服务
# 66     6848382  资深数据分析师（商品方向）G01053     179243   500-2000人      电商,移动互联网
# 67     5203054              资深数据分析师        329     2000人以上            电商
# 68     6829736     数据分析负责人 or 数据分析师     205347     2000人以上         金融,电商
# 69     6116460  资深数据分析/数据分析专家G00796     179243   500-2000人      电商,移动互联网
# 70     6728610             高级数据分析专员      98316     2000人以上       电商,消费生活
# 71     6793844              BI数据分析师     555182     50-150人      移动互联网,电商
# 72     6794326              BI数据分析师     374014   500-2000人      移动互联网,金融
# 73     6819289                数据分析师      28103     2000人以上       消费生活,硬件
# 74     6837340         数据分析-2020届春招     205347     2000人以上         金融,电商
# 75     6698172                数据分析师       2900   500-2000人            电商
# 76     6896403         智能数据分析引擎研发专家     285786     2000人以上            电商
# 77     6854920        数据分析师(J10147)     343064     2000人以上            电商
# 78     5683671   数据分析实习生 (MJ000087)     114335    150-500人          数据服务
# 79     6046866                数据分析师     543802      15-50人          数据服务
#
#    financeStage                    companyLabelList  firstType secondType  \
# 60        D轮及以上      ['技能培训', 'Geek', '开放', '扁平管理']  开发|测试|运维类       数据开发
# 61        D轮及以上      ['技能培训', 'Geek', '开放', '扁平管理']  综合职能|高级管理         财务
# 62        D轮及以上      ['技能培训', 'Geek', '开放', '扁平管理']  开发|测试|运维类       数据开发
# 63           B轮     ['股票期权', '弹性工作', '领导好', '五险一金']  产品|需求|项目类       产品经理
# 64          未融资    ['弹性工作', '技能培训', '岗位晋升', '五险一金']  开发|测试|运维类       数据开发
# 65           B轮    ['股票期权', '绩效奖金', '带薪年假', '弹性工作']  产品|需求|项目类       数据分析
# 66         上市公司    ['绩效奖金', '股票期权', '五险一金', '午餐补助']  产品|需求|项目类       数据分析
# 67         上市公司    ['节日礼物', '技能培训', '免费班车', '带薪年假']  产品|需求|项目类       数据分析
# 68         上市公司     ['带薪年假', '定期体检', '免费班车', '领导好']  开发|测试|运维类       数据开发
# 69         上市公司    ['绩效奖金', '股票期权', '五险一金', '午餐补助']  开发|测试|运维类       数据开发
# 70         上市公司    ['午餐补助', '带薪年假', '定期体检', '年度旅游']     市场|商务类      市场|营销
# 71          天使轮                                  []  运营|编辑|客服类         运营
# 72           B轮     ['弹性工作', '扁平管理', '领导好', '五险一金']  产品|需求|项目类       数据分析
# 73         上市公司  ['定期体检', '五险一金', '专项奖金', '骨干家庭公寓']  产品|需求|项目类       数据分析
# 74         上市公司     ['带薪年假', '定期体检', '免费班车', '领导好']  产品|需求|项目类       数据分析
# 75           C轮    ['扁平化管理', '技术驱动', '14薪', '六险一金']  产品|需求|项目类       数据分析
# 76         上市公司    ['年底双薪', '带薪年假', '午餐补助', '弹性工作']  开发|测试|运维类       后端开发
# 77        不需要融资    ['绩效奖金', '交通补助', '带薪年假', '定期体检']  产品|需求|项目类       产品经理
# 78           B轮     ['股票期权', '弹性工作', '领导好', '五险一金']  开发|测试|运维类       后端开发
# 79        不需要融资                                  []  产品|需求|项目类       数据分析
#
#    thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 60      数据分析  ...  NaN      0       0       0              NaN
# 61        财务  ...  NaN      0       0       0              NaN
# 62      数据分析  ...  NaN      0       0       0              NaN
# 63     数据分析师  ...  NaN      0       0       0              NaN
# 64      数据分析  ...  NaN      0       0       0              NaN
# 65      数据分析  ...  NaN      0       0       0              NaN
# 66      数据分析  ...  NaN      0       0       0              NaN
# 67      数据分析  ...  NaN      0       0       0              NaN
# 68      数据分析  ...  NaN      0       0       0              NaN
# 69      数据分析  ...  NaN      0       0       0              NaN
# 70    商业数据分析  ...  NaN      0       0       0              NaN
# 71        运营  ...  NaN      0       0       0              NaN
# 72        BI  ...  NaN      0       0       0              NaN
# 73      数据分析  ...  NaN      0       0       0              NaN
# 74      数据分析  ...  NaN      0       0       0              NaN
# 75      数据分析  ...  NaN      0       0       0              NaN
# 76      Java  ...  NaN      0       0       0              NaN
# 77     数据分析师  ...  NaN      0       0       0              NaN
# 78      数据采集  ...  NaN      0       0       0              NaN
# 79      数据分析  ...  NaN      0       0       0              NaN
#
#    promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 60                   NaN         0      0                   []          True
# 61                   NaN         0      0                   []          True
# 62                   NaN         0      0                   []          True
# 63                   NaN         0      0                   []         False
# 64                   NaN         0      0                   []         False
# 65                   NaN         0      0                   []         False
# 66                   NaN         0      0                   []          True
# 67                   NaN         0      0                   []          True
# 68                   NaN         0      0                   []          True
# 69                   NaN         0      0                   []          True
# 70                   NaN         0      0                   []         False
# 71                   NaN         0      0                   []         False
# 72                   NaN         0      0                   []         False
# 73                   NaN         0      0                   []          True
# 74                   NaN         0      0                   []          True
# 75                   NaN         0      0                   []          True
# 76                   NaN         0      0                   []          True
# 77                   NaN         0      0                   []         False
# 78                   NaN         0      0                   []         False
# 79                   NaN         0      0                   []         False
#
# [20 rows x 52 columns]
#     positionId             positionName  companyId companySize industryField  \
# 80     6310387                 业务与数据分析师      93448    150-500人     人工智能,数据服务
# 81     6602399          商业数据分析师（阿里数据银行）     100858     50-150人    移动互联网,广告营销
# 82     6820395  产品经理/数据分析（核心业务）-2020届春招     205347     2000人以上         金融,电商
# 83     6872841                  资深数据分析师        329     2000人以上            电商
# 84     6747553                  资深数据分析师     581460     2000人以上      电商,汽车丨出行
# 85     6792091                  高级数据分析师      23252   500-2000人         移动互联网
# 86     6496980               数据分析师-Lark         62     2000人以上         文娱丨内容
# 87     6095231           数据分析师-企业SaaS应用         62     2000人以上         文娱丨内容
# 88     6597345                  资深数据分析师      57350   500-2000人         移动互联网
# 89     6655791                     数据分析     289890   500-2000人            其他
# 90     6456921                   数据分析专家     738016     50-150人       电商,数据服务
# 91     6888169            奔驰耀出行-战略数据分析师     751158    150-500人         移动互联网
# 92     6813626                 资深数据分析专员     165939    150-500人          数据服务
# 93     6785139                    数据分析师     665061     50-150人          企业服务
# 94     6818950                  资深数据分析师     165939    150-500人          数据服务
# 95     5269002                  数据建模工程师      50576    150-500人      移动互联网,游戏
# 96     6767669                   数据分析专员      92417     2000人以上    移动互联网,广告营销
# 97     6718750             旅游大数据分析师（杭州）     122019     50-150人     数据服务,企业服务
# 98     6655562                数据分析建模工程师  117422215     50-150人     数据服务,信息安全
# 99     6677939            数据分析建模工程师（校招）  117422215     50-150人     数据服务,信息安全
#
#    financeStage                      companyLabelList  firstType secondType  \
# 80           B轮      ['技能培训', '股票期权', '带薪年假', '绩效奖金']  产品|需求|项目类       数据分析
# 81          天使轮      ['节日礼物', '带薪年假', '绩效奖金', '五险一金']     市场|商务类      市场|营销
# 82         上市公司       ['带薪年假', '定期体检', '免费班车', '领导好']  产品|需求|项目类       产品经理
# 83         上市公司      ['节日礼物', '技能培训', '免费班车', '带薪年假']  开发|测试|运维类       数据开发
# 84        D轮及以上       ['阿里合资', '六险一金', '独角兽', '行业先驱']     市场|商务类      市场|营销
# 85         上市公司  ['包午餐晚餐', '奖金多多多', '零食下午茶', '全员出国游']  产品|需求|项目类       数据分析
# 86           C轮  ['扁平管理', '弹性工作', '大厨定制三餐', '就近租房补贴']  产品|需求|项目类       数据分析
# 87           C轮  ['扁平管理', '弹性工作', '大厨定制三餐', '就近租房补贴']  产品|需求|项目类       数据分析
# 88           A轮      ['岗位晋升', '年度旅游', '年底双薪', '午餐补助']  产品|需求|项目类       数据分析
# 89          未融资                                    []  产品|需求|项目类       数据分析
# 90          未融资                                    []  开发|测试|运维类       数据开发
# 91        不需要融资                                    []  产品|需求|项目类       数据分析
# 92        不需要融资      ['年底双薪', '带薪年假', '午餐补助', '定期体检']  开发|测试|运维类       数据开发
# 93           B轮                                    []  开发|测试|运维类       数据开发
# 94        不需要融资      ['年底双薪', '带薪年假', '午餐补助', '定期体检']  开发|测试|运维类       数据开发
# 95           A轮        ['带薪年假', '五险一金', '双休', '午餐补助']  开发|测试|运维类       数据开发
# 96         上市公司      ['节日礼物', '股票期权', '带薪年假', '岗位晋升']  产品|需求|项目类       数据分析
# 97           A轮      ['年底双薪', '股票期权', '午餐补助', '定期体检']  开发|测试|运维类       数据开发
# 98           A轮   ['午餐补助', '带薪年假', '16到18薪', '法定节假日']  开发|测试|运维类       人工智能
# 99           A轮   ['午餐补助', '带薪年假', '16到18薪', '法定节假日']  开发|测试|运维类       人工智能
#
#    thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 80      数据分析  ...  NaN      0       0       0              NaN
# 81    商业数据分析  ...  NaN      0       0       0              NaN
# 82      产品经理  ...  NaN      0       0       0              NaN
# 83      数据分析  ...  NaN      0       0       0              NaN
# 84    商业数据分析  ...  NaN      0       0       0              NaN
# 85      数据分析  ...  NaN      0       0       0              NaN
# 86    其他数据分析  ...  NaN      0       0       0              NaN
# 87    其他数据分析  ...  NaN      0       0       0              NaN
# 88      数据分析  ...  NaN      0       0       0              NaN
# 89      数据分析  ...  NaN      0       0       0              NaN
# 90      数据分析  ...  NaN      0       0       0              NaN
# 91      数据分析  ...  NaN      0       0       0              NaN
# 92      数据分析  ...  NaN      0       0       0              NaN
# 93      数据分析  ...  NaN      0       0       0              NaN
# 94      数据分析  ...  NaN      0       0       0              NaN
# 95        建模  ...  NaN      0       0       0              NaN
# 96      数据分析  ...  NaN      0       0       0              NaN
# 97      数据治理  ...  NaN      0       0       0              NaN
# 98      机器学习  ...  NaN      0       0       0              NaN
# 99     算法工程师  ...  NaN      0       0       0              NaN
#
#    promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 80                   NaN         0      0                   []         False
# 81                   NaN         0      0                   []         False
# 82                   NaN         0      0                   []          True
# 83                   NaN         0      0                   []          True
# 84                   NaN         0      0                   []         False
# 85                   NaN         0      0                   []         False
# 86                   NaN         0      0                   []          True
# 87                   NaN         0      0                   []          True
# 88                   NaN         0      0                   []         False
# 89                   NaN         0      0                   []         False
# 90                   NaN         0      0                   []         False
# 91                   NaN         0      0                   []         False
# 92                   NaN         0      0                   []         False
# 93                   NaN         0      0                   []         False
# 94                   NaN         0      0                   []         False
# 95                   NaN         0      0                   []         False
# 96                   NaN         0      0                   []         False
# 97                   NaN         0      0                   []         False
# 98                   NaN         0      0                   []         False
# 99                   NaN         0      0                   []         False
#
# [20 rows x 52 columns]
#      positionId           positionName  companyId companySize industryField  \
# 100     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 101     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#     financeStage                  companyLabelList  firstType secondType  \
# 100           C轮  ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 101           C轮  ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 102        不需要融资                                []  开发|测试|运维类       数据开发
# 103         上市公司  ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 104        不需要融资  ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#     thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 100      数据分析  ...  NaN      0       0       0              NaN
# 101    商业数据分析  ...  NaN      0       0       0              NaN
# 102      数据分析  ...  NaN      0       0       0              NaN
# 103      数据分析  ...  NaN      0       0       0              NaN
# 104    其他数据分析  ...  NaN      0       0       0              NaN
#
#     promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 100                   NaN         0      0                   []         False
# 101                   NaN         0      0                   []         False
# 102                   NaN         0      0                   []         False
# 103                   NaN         0      0                   []          True
# 104                   NaN         0      0                   []          True
#
# [5 rows x 52 columns]

# %% [markdown]
# ### 17 读取 txt 文件｜常规
#
# <br>
#
# 读取当前目录下 `Titanic.txt` 文件。
#
# 注意：在接下来的几种格式文件读取中，对于之前重复的参数/功能将不再整理，仅介绍读取功能。

# %%
pd.read_csv('./Titanic.txt', sep="\t")
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %% [markdown]
# ### 18 读取 txt 文件｜含中文
#
# <br>
#
# 读取当前目录下 `TOP250.txt` 文件。

# %%
pd.read_csv("./TOP250.txt", sep="\t", encoding="gbk")
# Out:
#            片名  上映年份   评分     评价人数        导演  \
# 0      肖申克的救赎  1994  9.7  2317937  弗兰克·德拉邦特
# 1        霸王别姬  1993  9.6  1720638       陈凯歌
# 2        阿甘正传  1994  9.5  1743966  罗伯特·泽米吉斯
# 3     这个杀手不太冷  1994  9.4  1922740     吕克·贝松
# 4       泰坦尼克号  1997  9.4  1706127   詹姆斯·卡梅隆
# ..        ...   ...  ...      ...       ...
# 245        浪潮  2008  8.7   223511   丹尼斯·甘塞尔
# 246  小萝莉的猴神大叔  2015  8.4   404886     卡比尔·汗
# 247        追随  1998  8.9   149521  克里斯托弗·诺兰
# 248      网络谜踪  2018  8.6   430811   阿尼什·查甘蒂
# 249      黑鹰坠落  2001  8.7   239402   雷德利·斯科特
#
#                                                编剧  \
# 0                                弗兰克·德拉邦特 / 斯蒂芬·金
# 1                                        芦苇 / 李碧华
# 2                                艾瑞克·罗斯 / 温斯顿·格鲁姆
# 3                                           吕克·贝松
# 4                                         詹姆斯·卡梅隆
# ..                                            ...
# 245  丹尼斯·甘塞尔 / 彼得·图万斯 / 约翰尼·道金斯 / 罗恩·比恩巴赫 / 罗恩·琼斯
# 246                            卡比尔·汗 / 维杰耶德拉·普拉萨德
# 247                                      克里斯托弗·诺兰
# 248                             阿尼什·查甘蒂 / 赛弗·奥哈尼安
# 249                                  肯·诺兰 / 马克·鲍登
#
#                                                     主演                 类型  \
# 0    蒂姆·罗宾斯 / 摩根·弗里曼 / 鲍勃·冈顿 / 威廉姆·赛德勒 / 克兰西·布朗 / 吉...            剧情 / 犯罪
# 1    张国荣 / 张丰毅 / 巩俐 / 葛优 / 英达 / 蒋雯丽 / 吴大维 / 吕齐 / 雷汉...       剧情 / 爱情 / 同性
# 2    汤姆·汉克斯 / 罗宾·怀特 / 加里·西尼斯 / 麦凯尔泰·威廉逊 / 莎莉·菲尔德 / ...            剧情 / 爱情
# 3    让·雷诺 / 娜塔莉·波特曼 / 加里·奥德曼 / 丹尼·爱罗 / 彼得·阿佩尔 / 迈克尔...       剧情 / 动作 / 犯罪
# 4    莱昂纳多·迪卡普里奥 / 凯特·温丝莱特 / 比利·赞恩 / 凯西·贝茨 / 弗兰西丝·费舍...       剧情 / 爱情 / 灾难
# ..                                                 ...                ...
# 245  于尔根·福格尔 / 弗雷德里克·劳 / 马克思·雷迈特 / 詹妮弗·乌尔里希 / 克里斯蒂安...            剧情 / 惊悚
# 246  萨尔曼·汗 / 哈莎莉·马洛特拉 / 卡琳娜·卡普尔 / 纳瓦祖丁·席迪圭 / 欧姆·普瑞 ...       剧情 / 喜剧 / 动作
# 247  杰里米·西奥伯德 / 亚历克斯·霍 / 露西·拉塞尔 / 约翰·诺兰 / 迪克·布拉德塞尔 ...       悬疑 / 惊悚 / 犯罪
# 248  约翰·赵 / 米切尔·拉 / 黛博拉·梅辛 / 约瑟夫·李 / 萨拉·米博·孙 / 亚历克丝...  剧情 / 悬疑 / 惊悚 / 犯罪
# 249  乔什·哈奈特 / 伊万·麦克格雷格 / 汤姆·塞兹摩尔 / 金·寇兹 / 艾文·布莱纳 / ...       动作 / 历史 / 战争
#
#     国家/地区     语言  时长(分钟)
# 0      美国     英语     142
# 1      中国  汉语普通话     171
# 2      美国     英语     142
# 3      法国    英语      110
# 4      美国    英语      194
# ..    ...    ...     ...
# 245    德国     德语     107
# 246    印度   印地语      159
# 247    英国     英语      69
# 248    美国     英语     102
# 249    美国    英语      144
#
# [250 rows x 11 columns]

# %% [markdown]
# ### 19 读取 JSON 文件
#
# <br>
#
# 读取当前目录下 `某基金数据.json` 文件。

# %%
pd.read_json('./某基金数据.json')
# Out:
#          净值日期   单位净值   累计净值    日增长率  申购状态  赎回状态  分红送配
# 0  2020-02-13  1.884  1.884  -0.11%  开放申购  开放赎回   NaN
# 1  2020-02-12  1.886  1.886   3.34%  开放申购  开放赎回   NaN
# 2  2020-02-11  1.825  1.825  -0.16%  开放申购  开放赎回   NaN
# 3  2020-02-10  1.828  1.828   1.33%  开放申购  开放赎回   NaN
# 4  2020-02-07  1.804  1.804   0.61%  开放申购  开放赎回   NaN
# 5  2020-02-06  1.793  1.793   3.11%  开放申购  开放赎回   NaN
# 6  2020-02-05  1.739  1.739   1.64%  开放申购  开放赎回   NaN
# 7  2020-02-04  1.711  1.711   7.34%  开放申购  开放赎回   NaN
# 8  2020-02-03  1.594  1.594  -7.22%  开放申购  开放赎回   NaN
# 9  2020-01-23  1.718  1.718  -2.05%  开放申购  开放赎回   NaN

# %% [markdown]
# ### 20 读取 HDF5 文件
#
# <br>
#
# `HDF5`是一种特殊的文件格式，常见于在大规模存储数据上
#
# 关于 `pandas` 与 `hdf5` 格式文件的操作较多，下面仅学习如何读取。
#
# 读取当前目录下`store_tl.h5`文件

# %%
with pd.HDFStore('./store_tl.h5', mode='r') as hdf:
    print(hdf.keys())
    
pd.read_hdf('./store_tl.h5', key='/table')
# Out:
# ['/', '/table']
#        A    B
# 0      0    0
# 1      1    1
# 2      2    2
# 3      3    3
# 4      4    4
# ..   ...  ...
# 495  495  495
# 496  496  496
# 497  497  497
# 498  498  498
# 499  499  499
#
# [505 rows x 2 columns]

# %% [markdown]
# 微信搜索公众号「早起 Python」，关注后可以获得更多资源！

# %% [markdown]
# ### 21 从剪贴板读取数据
#
# <br>
#
# 打开当前目录下 `Titanic.txt` 文件，全选并复制。
#
# 现在直接从剪贴板读取数据。

# %%
pd.read_clipboard(sep="\t")
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %% [markdown]
# ### 22 从 SQL 读取数据
#
# <br>
#
# 有时我们需要从 `SQL` 中读取数据，如果先将数据导出再`pandas`读取并不是一个合适的选择。
#
# 在 `pandas` 中支持直接从 `sql` 中查询并读取。
#
# 为了方便统一操作，请先执行下面的代码创建数据。

# %%
from sqlite3 import connect

# :memory: 意为内存中创建
conn = connect(":memory:")
df = pd.DataFrame(
    data=[[0, "10/11/12"], [1, "12/11/10"]], columns=["int_column", "date_column"]
)
df.to_sql("test_data", conn)
# Out:
# 2

# %% [markdown]
# 下面将 `SQL` 语句 `SELECT int_column, date_column FROM test_data` 转换为 `DataFrame`

# %%
pd.read_sql_query("SELECT int_column, date_column FROM test_data", conn)
# Out:
#    int_column date_column
# 0           0    10/11/12
# 1           1    12/11/10

# %% [markdown]
# ### 23 从网页读取数据
#
# <br>
#
# 直接从东京奥运会官网读取奖牌榜数据。
#
# 目标网站地址为 `https://olympics.com/tokyo-2020/olympic-games/zh/results/all-sports/medal-standings.htm`
#
# 思考：什么类型的在线表格可以直接读取？

# %%
df_list = pd.read_html(
    "https://www.runoob.com/numpy/numpy-ndarray-object.html", header=0
)
df_list[0]
# Out:
#        名称                              描述
# 0  object                        数组或嵌套的数列
# 1   dtype                    数组元素的数据类型，可选
# 2    copy                     对象是否需要复制，可选
# 3   order  创建数组的样式，C为行方向，F为列方向，A为任意方向（默认）
# 4   subok                默认返回一个与基类类型一致的数组
# 5   ndmin                     指定生成数组的最小维度

# %% [markdown]
# ### 24 循环读取数据
#
# <br>
#
# 在本小节 `demodata` 文件夹下有多个 `Excel` 文件，要求一次性循环读取全部文件

# %%
import os

# 设置文件夹路径
folder_path = './demodata/'

# 初始化一个空的DataFrame，用于存储所有文件的数据
all_data = pd.DataFrame()

# 遍历文件夹中的所有文件
for filename in os.listdir(folder_path):
    # 检查文件扩展名是否为.xlsx或.xls
    if filename.endswith('.xlsx') or filename.endswith('.xls'):
        # 构建完整的文件路径
        file_path = os.path.join(folder_path, filename)
        
        # 读取Excel文件
        df = pd.read_excel(file_path, na_filter=False)
        
        # 将读取的数据追加到all_data DataFrame中
        all_data = pd.concat([all_data, df], ignore_index=True)

all_data
# Out:
#               日期  日增长率    涨跌          持有金额   剩余本金   操作           总资产
# 0     2020-01-02  2.92    up      0.000000  20000       20000.000000
# 1     2020-01-03  0.51    up      0.000000  20000       20000.000000
# 2     2020-01-06  1.98    up      0.000000  20000       20000.000000
# 3     2020-01-07  0.17    up      0.000000  20000       20000.000000
# 4     2020-01-08 -1.16  down      0.000000  20000       20000.000000
# ...          ...   ...   ...           ...    ...  ...           ...
# 3405  2021-05-26 -0.12  down  20372.810590   4700       25072.810590
# 3406  2021-05-27  0.66    up  20507.271140   4700  buy  25207.271140
# 3407  2021-05-28 -0.30  down  20545.329687   4600       25145.329687
# 3408  2021-05-31  0.06    up  20557.656885   4600  buy  25157.656885
# 3409  2021-06-01  0.42    up  20744.298540   4500       25244.298540
#
# [3410 rows x 7 columns]

# %% [markdown]
# ## 1-2 数据创建
#
# <br>
#
# 除了直接读取本地文件，学会直接创建数据框也很重要，常见于测试一些函数，下面是从常见数据结构创建数据框的方法整理

# %% [markdown]
# ### 25 从列表创建
#
# <br>
#
# 将下面的 `list` 转换为 `dataframe`，并指定列名为`"早起Python"`

# %%
l = [1, 2, 3, 4, 5]

# %% [markdown]
# ### 26 从列表创建｜嵌套列表
#
# <br>
#
# 将下面的 `list` 转换为 `dataframe`，并指定行索引为`"公众号","早起Python"`

# %%
l = [[1, 2, 3], [4, 5, 6]]

# %% [markdown]
# ![公众号：早起Python](http://liuzaoqi.oss-cn-beijing.aliyuncs.com/2021/09/18/16319660121648.jpg?域名/sample.jpg?x-oss-process=style/stylename)

# %% [markdown]
# ### 27 从字典创建

# %% [markdown]
# 执行下方代码，并将字典转换为`dataframe`

# %%
d = {
    "one": pd.Series([1.0, 2.0, 3.0], index=["a", "b", "c"]),
    "two": pd.Series([1.0, 2.0, 3.0, 4.0], index=["a", "b", "c", "d"]),
}

# %% [markdown]
# ### 28 从字典创建｜指定索引
#
# <br>
#
# 还是上一题的字典`d`，将其转换为`dataframe`并指定索引顺序为 `d、b、a`

# %% [markdown]
# ### 29 从字典创建｜指定列名
#
# <br>
#
# 还是上一题的字典`d`，将其转换为`dataframe`并指定索引顺序为 `d、b、a`，列名为`"two", "three"`

# %% [markdown]
# ### 30 从字典创建｜字典列表
#
# <br>
#
# 将下方列表型字典转换为`dataframe`
#
# 思考：如何指定行/列索引？

# %%
d = [{"a": 1, "b": 2}, {"a": 5, "b": 10, "c": 20}]

# %% [markdown]
# ### 31 从集合创建
#
# <br>
#
# 将下面的元组转换为 dataframe 且行列索引均为 `1,2,3,4`

# %%
t = (
    (
        1,
        0,
        0,
        0,
    ),
    (
        2,
        3,
        0,
        0,
    ),
    (
        4,
        5,
        6,
        0,
    ),
    (
        7,
        8,
        9,
        10,
    ),
)

# %% [markdown]
# ## 1-3 数据存储

# %% [markdown]
# ### 32 保存为 CSV
#
# <br>
#
# 将第三题读取到的数据保存为 `csv` 格式至当前目录下（文件名任意）

# %%
data = pd.read_csv("某招聘网站数据.csv", nrows=20)

# %% [markdown]
# ### 33 保存为 CSV ｜指定列
#
# <br>
#
# 将第三题读取到的数据保存为 `csv` 格式至当前目录下（文件名任意），且只保留`positionName、salary`两列

# %% [markdown]
# ### 34 保存为 CSV ｜取消索引
#
# <br>
#
# 将第三题读取到的数据保存为 `csv` 格式至当前目录下（文件名任意），且取消每一行的索引

# %% [markdown]
# ### 35 保存为 CSV ｜标记缺失值
#
# <br>
#
# 在上一题的基础上，在保存的同时，将缺失值标记为`'数据缺失'`

# %% [markdown]
# ### 36 保存为 CSV ｜压缩
#
# <br>
#
# 将上一题的数据保存至 `zip` 文件，解压后出现 `out.csv`

# %% [markdown]
# ### 37 保存为 Excel
#
# <br>
#
# 将第三题读取到的数据保存为 `xlsx` 格式至当前目录下（文件名任意）

# %% [markdown]
# ### 38 保存为 JSON
#
# 将之前的数据保存为 `json` 格式至当前目录下（文件名任意）

# %% [markdown]
# ### 39 保存为 Markdown

# %% [markdown]
# 将之前数据转换为 `markdown` 形式表格，这样可以直接复制进 `.md` 文件中使用

# %% [markdown]
# ### 40 保存为 Html
#
# 将之前的数据保存为 `html` 格式至当前目录下（文件名任意），并进行如下设置
#
# - 取消行索引
# - 标题居中对齐
# - 列宽 100

# %% [markdown]
# ![](http://liuzaoqi.oss-cn-beijing.aliyuncs.com/2021/09/16/16317972442543.jpg?域名/sample.jpg?x-oss-process=style/stylename)
